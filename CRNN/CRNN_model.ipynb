# %%
import torch.nn as nn
from config import train_config as config
from CRNN_Dataset import SVHC_Dataset, SVHC_collate_fn
from torchsummary import summary
import torch

# %%
class CRNN(nn.Module):

    def __init__(self, img_channel, img_height, img_width, num_class,
                 map_to_seq_hidden=64, rnn_hidden=256, leaky_relu=False):
        super(CRNN, self).__init__()
        '''
           img_channel:如果是灰度图像则为1
           img_height：32
           img_width：100
           num_class: 要实现多少个字符，这里是26个
           map_to_seq_hidden: CNN 向 RNN的过度
           rnn——hidden： rnn的隐藏层
        '''
        self.cnn, (output_channel, output_height, output_width) = \
            self._cnn_backbone(img_channel, img_height, img_width, leaky_relu)

        self.map_to_seq = nn.Linear(output_channel * output_height, map_to_seq_hidden)

        self.rnn1 = nn.LSTM(map_to_seq_hidden, rnn_hidden, bidirectional=True)

        # 如果接双向lstm输出，则要 *2,固定用法
        self.rnn2 = nn.LSTM(2 * rnn_hidden, rnn_hidden, bidirectional=True)

        self.dense = nn.Linear(2 * rnn_hidden, num_class)

    # CNN主干网络
    def _cnn_backbone(self, img_channel, img_height, img_width, leaky_relu):
        assert img_height % 16 == 0
        assert img_width % 4 == 0

        # 超参设置
        channels = [img_channel, 64, 128, 256, 256, 512, 512, 512]
        kernel_sizes = [3, 3, 3, 3, 3, 3, 2]
        strides = [1, 1, 1, 1, 1, 1, 1]
        paddings = [1, 1, 1, 1, 1, 1, 0]

        cnn = nn.Sequential()

        def conv_relu(i, batch_norm=False):
            # shape of input: (batch, input_channel, height, width)
            input_channel = channels[i]
            output_channel = channels[i+1]

            cnn.add_module(
                f'conv{i}',
                nn.Conv2d(input_channel, output_channel, kernel_sizes[i], strides[i], paddings[i])
            )

            if batch_norm:
                cnn.add_module(f'batchnorm{i}', nn.BatchNorm2d(output_channel))

            relu = nn.LeakyReLU(0.2, inplace=True) if leaky_relu else nn.ReLU(inplace=True)
            cnn.add_module(f'relu{i}', relu)

        # size of image: (channel, height, width) = (img_channel, img_height, img_width)
        conv_relu(0)
        cnn.add_module('pooling0', nn.MaxPool2d(kernel_size=2, stride=2))
        # (64, img_height // 2, img_width // 2)

        conv_relu(1)
        cnn.add_module('pooling1', nn.MaxPool2d(kernel_size=2, stride=2))
        # (128, img_height // 4, img_width // 4)

        conv_relu(2)
        conv_relu(3)
        cnn.add_module(
            'pooling2',
            nn.MaxPool2d(kernel_size=(2, 1))
        )  # (256, img_height // 8, img_width // 4)

        conv_relu(4, batch_norm=True)
        conv_relu(5, batch_norm=True)
        cnn.add_module(
            'pooling3',
            nn.MaxPool2d(kernel_size=(2, 1))
        )  # (512, img_height // 16, img_width // 4)

        conv_relu(6)  # (512, img_height // 16 - 1, img_width // 4 - 1)

        output_channel, output_height, output_width = \
            channels[-1], img_height // 16 - 1, img_width // 4 - 1
        return cnn, (output_channel, output_height, output_width)

    # CNN+LSTM前向计算
    def forward(self, images):
        # shape of images: (batch, channel, height, width)

        conv = self.cnn(images)
        batch, channel, height, width = conv.size()

        conv = conv.view(batch, channel * height, width)
        conv = conv.permute(2, 0, 1)  # (width, batch, feature)

        # 卷积接全连接。全连接输入形状为(width, batch, channel*height)，
        # 输出形状为(width, batch, hidden_layer)，分别对应时序长度，batch，特征数，符合LSTM输入要求
        seq = self.map_to_seq(conv)

        recurrent, _ = self.rnn1(seq)
        recurrent, _ = self.rnn2(recurrent)

        output = self.dense(recurrent)
        return output  # shape: (seq_len, batch, num_class)

# %%
img_width = config['img_width']
img_height = config['img_height']

num_class = len(SVHC_Dataset.seq_to_char) + 1 # 加1是因为 L' = L +{blank} 加一个空白

# %%
img_width,img_height,num_class
# Out:
# (32, 32, 11)

# %%
crnn = CRNN(1, img_height, img_width, num_class,
            map_to_seq_hidden=config['map_to_seq_hidden'],
            rnn_hidden=config['rnn_hidden'],
            leaky_relu=config['leaky_relu'])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'device: {device}')
# Out:
# device: cuda

# %%
crnn.to(device)
# Out:
# CRNN(
#   (cnn): Sequential(
#     (conv0): Conv2d(1, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu0): ReLU(inplace=True)
#     (pooling0): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu1): ReLU(inplace=True)
#     (pooling1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (conv2): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu2): ReLU(inplace=True)
#     (conv3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu3): ReLU(inplace=True)
#     (pooling2): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#     (conv4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batchnorm4): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu4): ReLU(inplace=True)
#     (conv5): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (batchnorm5): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu5): ReLU(inplace=True)
#     (pooling3): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#     (conv6): Conv2d(512, 512, kernel_size=(2, 2), stride=(1, 1))
#     (relu6): ReLU(inplace=True)
#   )
#   (map_to_seq): Linear(in_features=512, out_features=64, bias=True)
#   (rnn1): LSTM(64, 256, bidirectional=True)
#   (rnn2): LSTM(512, 256, bidirectional=True)
#   (dense): Linear(in_features=512, out_features=11, bias=True)
# )

# %%
from tensorboardX import SummaryWriter

# %%
writer = SummaryWriter('F:/log') #建立一个保存数据用的东西

# %%
dummy_input = torch.rand(20, 1, 32, 32)
dummy_input = dummy_input.to(device)

writer.add_graph(crnn, (dummy_input),True)
writer.close()
# Out:
# graph(%self.1 : __torch__.___torch_mangle_335.CRNN,
#       %input.1 : Float(20, 1, 32, 32)):
#   %536 : __torch__.torch.nn.modules.linear.___torch_mangle_334.Linear = prim::GetAttr[name="dense"](%self.1)
#   %533 : __torch__.torch.nn.modules.rnn.___torch_mangle_333.LSTM = prim::GetAttr[name="rnn2"](%self.1)
#   %524 : __torch__.torch.nn.modules.rnn.___torch_mangle_332.LSTM = prim::GetAttr[name="rnn1"](%self.1)
#   %515 : __torch__.torch.nn.modules.linear.___torch_mangle_331.Linear = prim::GetAttr[name="map_to_seq"](%self.1)
#   %512 : __torch__.torch.nn.modules.container.___torch_mangle_330.Sequential = prim::GetAttr[name="cnn"](%self.1)
#   %567 : __torch__.torch.nn.modules.activation.___torch_mangle_329.ReLU = prim::GetAttr[name="relu6"](%512)
#   %568 : __torch__.torch.nn.modules.conv.___torch_mangle_328.Conv2d = prim::GetAttr[name="conv6"](%512)
#   %569 : __torch__.torch.nn.modules.pooling.___torch_mangle_327.MaxPool2d = prim::GetAttr[name="pooling3"](%512)
#   %570 : __torch__.torch.nn.modules.activation.___torch_mangle_326.ReLU = prim::GetAttr[name="relu5"](%512)
#   %571 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_325.BatchNorm2d = prim::GetAttr[name="batchnorm5"](%512)
#   %572 : __torch__.torch.nn.modules.conv.___torch_mangle_324.Conv2d = prim::GetAttr[name="conv5"](%512)
#   %573 : __torch__.torch.nn.modules.activation.___torch_mangle_323.ReLU = prim::GetAttr[name="relu4"](%512)
#   %574 : __torch__.torch.nn.modules.batchnorm.___torch_mangle_322.BatchNorm2d = prim::GetAttr[name="batchnorm4"](%512)
#   %575 : __torch__.torch.nn.modules.conv.___torch_mangle_321.Conv2d = prim::GetAttr[name="conv4"](%512)
#   %576 : __torch__.torch.nn.modules.pooling.___torch_mangle_320.MaxPool2d = prim::GetAttr[name="pooling2"](%512)
#   %577 : __torch__.torch.nn.modules.activation.___torch_mangle_319.ReLU = prim::GetAttr[name="relu3"](%512)
#   %578 : __torch__.torch.nn.modules.conv.___torch_mangle_318.Conv2d = prim::GetAttr[name="conv3"](%512)
#   %579 : __torch__.torch.nn.modules.activation.___torch_mangle_317.ReLU = prim::GetAttr[name="relu2"](%512)
#   %580 : __torch__.torch.nn.modules.conv.___torch_mangle_316.Conv2d = prim::GetAttr[name="conv2"](%512)
#   %581 : __torch__.torch.nn.modules.pooling.___torch_mangle_315.MaxPool2d = prim::GetAttr[name="pooling1"](%512)
#   %582 : __torch__.torch.nn.modules.activation.___torch_mangle_314.ReLU = prim::GetAttr[name="relu1"](%512)
#   %583 : __torch__.torch.nn.modules.conv.___torch_mangle_313.Conv2d = prim::GetAttr[name="conv1"](%512)
#   %584 : __torch__.torch.nn.modules.pooling.___torch_mangle_312.MaxPool2d = prim::GetAttr[name="pooling0"](%512)
#   %585 : __torch__.torch.nn.modules.activation.___torch_mangle_311.ReLU = prim::GetAttr[name="relu0"](%512)
#   %586 : __torch__.torch.nn.modules.conv.___torch_mangle_310.Conv2d = prim::GetAttr[name="conv0"](%512)
#   %587 : Tensor = prim::GetAttr[name="bias"](%586)
#   %588 : Tensor = prim::GetAttr[name="weight"](%586)
#   %589 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %590 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %591 : int[] = prim::ListConstruct(%589, %590), scope: __module.cnn/__module.cnn.conv0
#   %592 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %593 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %594 : int[] = prim::ListConstruct(%592, %593), scope: __module.cnn/__module.cnn.conv0
#   %595 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %596 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %597 : int[] = prim::ListConstruct(%595, %596), scope: __module.cnn/__module.cnn.conv0
#   %598 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %599 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %600 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %601 : int[] = prim::ListConstruct(%599, %600), scope: __module.cnn/__module.cnn.conv0
#   %602 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %603 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %604 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %605 : bool = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %input.2 : Float(20, 64, 32, 32) = aten::_convolution(%input.1, %588, %587, %591, %594, %597, %598, %601, %602, %603, %604, %605), scope: __module.cnn/__module.cnn.conv0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %input.3 : Float(20, 64, 32, 32) = aten::relu_(%input.2), scope: __module.cnn/__module.cnn.relu0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1061:0
#   %608 : int = prim::Constant[value=2](), scope: __module.cnn/__module.cnn.pooling0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %609 : int = prim::Constant[value=2](), scope: __module.cnn/__module.cnn.pooling0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %610 : int[] = prim::ListConstruct(%608, %609), scope: __module.cnn/__module.cnn.pooling0
#   %611 : int = prim::Constant[value=2](), scope: __module.cnn/__module.cnn.pooling0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %612 : int = prim::Constant[value=2](), scope: __module.cnn/__module.cnn.pooling0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %613 : int[] = prim::ListConstruct(%611, %612), scope: __module.cnn/__module.cnn.pooling0
#   %614 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.pooling0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %615 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.pooling0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %616 : int[] = prim::ListConstruct(%614, %615), scope: __module.cnn/__module.cnn.pooling0
#   %617 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.pooling0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %618 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.pooling0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %619 : int[] = prim::ListConstruct(%617, %618), scope: __module.cnn/__module.cnn.pooling0
#   %620 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.pooling0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %input.4 : Float(20, 64, 16, 16) = aten::max_pool2d(%input.3, %610, %613, %616, %619, %620), scope: __module.cnn/__module.cnn.pooling0 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %622 : Tensor = prim::GetAttr[name="bias"](%583)
#   %623 : Tensor = prim::GetAttr[name="weight"](%583)
#   %624 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %625 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %626 : int[] = prim::ListConstruct(%624, %625), scope: __module.cnn/__module.cnn.conv1
#   %627 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %628 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %629 : int[] = prim::ListConstruct(%627, %628), scope: __module.cnn/__module.cnn.conv1
#   %630 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %631 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %632 : int[] = prim::ListConstruct(%630, %631), scope: __module.cnn/__module.cnn.conv1
#   %633 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %634 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %635 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %636 : int[] = prim::ListConstruct(%634, %635), scope: __module.cnn/__module.cnn.conv1
#   %637 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %638 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %639 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %640 : bool = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %input.5 : Float(20, 128, 16, 16) = aten::_convolution(%input.4, %623, %622, %626, %629, %632, %633, %636, %637, %638, %639, %640), scope: __module.cnn/__module.cnn.conv1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %input.6 : Float(20, 128, 16, 16) = aten::relu_(%input.5), scope: __module.cnn/__module.cnn.relu1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1061:0
#   %643 : int = prim::Constant[value=2](), scope: __module.cnn/__module.cnn.pooling1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %644 : int = prim::Constant[value=2](), scope: __module.cnn/__module.cnn.pooling1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %645 : int[] = prim::ListConstruct(%643, %644), scope: __module.cnn/__module.cnn.pooling1
#   %646 : int = prim::Constant[value=2](), scope: __module.cnn/__module.cnn.pooling1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %647 : int = prim::Constant[value=2](), scope: __module.cnn/__module.cnn.pooling1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %648 : int[] = prim::ListConstruct(%646, %647), scope: __module.cnn/__module.cnn.pooling1
#   %649 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.pooling1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %650 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.pooling1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %651 : int[] = prim::ListConstruct(%649, %650), scope: __module.cnn/__module.cnn.pooling1
#   %652 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.pooling1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %653 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.pooling1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %654 : int[] = prim::ListConstruct(%652, %653), scope: __module.cnn/__module.cnn.pooling1
#   %655 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.pooling1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %input.7 : Float(20, 128, 8, 8) = aten::max_pool2d(%input.6, %645, %648, %651, %654, %655), scope: __module.cnn/__module.cnn.pooling1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %657 : Tensor = prim::GetAttr[name="bias"](%580)
#   %658 : Tensor = prim::GetAttr[name="weight"](%580)
#   %659 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %660 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %661 : int[] = prim::ListConstruct(%659, %660), scope: __module.cnn/__module.cnn.conv2
#   %662 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %663 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %664 : int[] = prim::ListConstruct(%662, %663), scope: __module.cnn/__module.cnn.conv2
#   %665 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %666 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %667 : int[] = prim::ListConstruct(%665, %666), scope: __module.cnn/__module.cnn.conv2
#   %668 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %669 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %670 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %671 : int[] = prim::ListConstruct(%669, %670), scope: __module.cnn/__module.cnn.conv2
#   %672 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %673 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %674 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %675 : bool = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %input.8 : Float(20, 256, 8, 8) = aten::_convolution(%input.7, %658, %657, %661, %664, %667, %668, %671, %672, %673, %674, %675), scope: __module.cnn/__module.cnn.conv2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %input.9 : Float(20, 256, 8, 8) = aten::relu_(%input.8), scope: __module.cnn/__module.cnn.relu2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1061:0
#   %678 : Tensor = prim::GetAttr[name="bias"](%578)
#   %679 : Tensor = prim::GetAttr[name="weight"](%578)
#   %680 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %681 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %682 : int[] = prim::ListConstruct(%680, %681), scope: __module.cnn/__module.cnn.conv3
#   %683 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %684 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %685 : int[] = prim::ListConstruct(%683, %684), scope: __module.cnn/__module.cnn.conv3
#   %686 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %687 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %688 : int[] = prim::ListConstruct(%686, %687), scope: __module.cnn/__module.cnn.conv3
#   %689 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %690 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %691 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %692 : int[] = prim::ListConstruct(%690, %691), scope: __module.cnn/__module.cnn.conv3
#   %693 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %694 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %695 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %696 : bool = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %input.10 : Float(20, 256, 8, 8) = aten::_convolution(%input.9, %679, %678, %682, %685, %688, %689, %692, %693, %694, %695, %696), scope: __module.cnn/__module.cnn.conv3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %input.11 : Float(20, 256, 8, 8) = aten::relu_(%input.10), scope: __module.cnn/__module.cnn.relu3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1061:0
#   %699 : int = prim::Constant[value=2](), scope: __module.cnn/__module.cnn.pooling2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %700 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.pooling2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %701 : int[] = prim::ListConstruct(%699, %700), scope: __module.cnn/__module.cnn.pooling2
#   %702 : int = prim::Constant[value=2](), scope: __module.cnn/__module.cnn.pooling2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %703 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.pooling2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %704 : int[] = prim::ListConstruct(%702, %703), scope: __module.cnn/__module.cnn.pooling2
#   %705 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.pooling2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %706 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.pooling2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %707 : int[] = prim::ListConstruct(%705, %706), scope: __module.cnn/__module.cnn.pooling2
#   %708 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.pooling2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %709 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.pooling2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %710 : int[] = prim::ListConstruct(%708, %709), scope: __module.cnn/__module.cnn.pooling2
#   %711 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.pooling2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %input.12 : Float(20, 256, 4, 8) = aten::max_pool2d(%input.11, %701, %704, %707, %710, %711), scope: __module.cnn/__module.cnn.pooling2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %713 : Tensor = prim::GetAttr[name="bias"](%575)
#   %714 : Tensor = prim::GetAttr[name="weight"](%575)
#   %715 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %716 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %717 : int[] = prim::ListConstruct(%715, %716), scope: __module.cnn/__module.cnn.conv4
#   %718 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %719 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %720 : int[] = prim::ListConstruct(%718, %719), scope: __module.cnn/__module.cnn.conv4
#   %721 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %722 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %723 : int[] = prim::ListConstruct(%721, %722), scope: __module.cnn/__module.cnn.conv4
#   %724 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %725 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %726 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %727 : int[] = prim::ListConstruct(%725, %726), scope: __module.cnn/__module.cnn.conv4
#   %728 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %729 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %730 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %731 : bool = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %input.13 : Float(20, 512, 4, 8) = aten::_convolution(%input.12, %714, %713, %717, %720, %723, %724, %727, %728, %729, %730, %731), scope: __module.cnn/__module.cnn.conv4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %733 : Tensor = prim::GetAttr[name="running_var"](%574)
#   %734 : Tensor = prim::GetAttr[name="running_mean"](%574)
#   %735 : Tensor = prim::GetAttr[name="bias"](%574)
#   %736 : Tensor = prim::GetAttr[name="weight"](%574)
#   %737 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.batchnorm4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1923:0
#   %738 : float = prim::Constant[value=0.10000000000000001](), scope: __module.cnn/__module.cnn.batchnorm4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1923:0
#   %739 : float = prim::Constant[value=1.0000000000000001e-05](), scope: __module.cnn/__module.cnn.batchnorm4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1923:0
#   %740 : bool = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.batchnorm4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1923:0
#   %input.14 : Float(20, 512, 4, 8) = aten::batch_norm(%input.13, %736, %735, %734, %733, %737, %738, %739, %740), scope: __module.cnn/__module.cnn.batchnorm4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1923:0
#   %input.15 : Float(20, 512, 4, 8) = aten::relu_(%input.14), scope: __module.cnn/__module.cnn.relu4 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1061:0
#   %743 : Tensor = prim::GetAttr[name="bias"](%572)
#   %744 : Tensor = prim::GetAttr[name="weight"](%572)
#   %745 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %746 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %747 : int[] = prim::ListConstruct(%745, %746), scope: __module.cnn/__module.cnn.conv5
#   %748 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %749 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %750 : int[] = prim::ListConstruct(%748, %749), scope: __module.cnn/__module.cnn.conv5
#   %751 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %752 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %753 : int[] = prim::ListConstruct(%751, %752), scope: __module.cnn/__module.cnn.conv5
#   %754 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %755 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %756 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %757 : int[] = prim::ListConstruct(%755, %756), scope: __module.cnn/__module.cnn.conv5
#   %758 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %759 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %760 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %761 : bool = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %input.16 : Float(20, 512, 4, 8) = aten::_convolution(%input.15, %744, %743, %747, %750, %753, %754, %757, %758, %759, %760, %761), scope: __module.cnn/__module.cnn.conv5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %763 : Tensor = prim::GetAttr[name="running_var"](%571)
#   %764 : Tensor = prim::GetAttr[name="running_mean"](%571)
#   %765 : Tensor = prim::GetAttr[name="bias"](%571)
#   %766 : Tensor = prim::GetAttr[name="weight"](%571)
#   %767 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.batchnorm5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1923:0
#   %768 : float = prim::Constant[value=0.10000000000000001](), scope: __module.cnn/__module.cnn.batchnorm5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1923:0
#   %769 : float = prim::Constant[value=1.0000000000000001e-05](), scope: __module.cnn/__module.cnn.batchnorm5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1923:0
#   %770 : bool = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.batchnorm5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1923:0
#   %input.17 : Float(20, 512, 4, 8) = aten::batch_norm(%input.16, %766, %765, %764, %763, %767, %768, %769, %770), scope: __module.cnn/__module.cnn.batchnorm5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1923:0
#   %input.18 : Float(20, 512, 4, 8) = aten::relu_(%input.17), scope: __module.cnn/__module.cnn.relu5 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1061:0
#   %773 : int = prim::Constant[value=2](), scope: __module.cnn/__module.cnn.pooling3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %774 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.pooling3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %775 : int[] = prim::ListConstruct(%773, %774), scope: __module.cnn/__module.cnn.pooling3
#   %776 : int = prim::Constant[value=2](), scope: __module.cnn/__module.cnn.pooling3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %777 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.pooling3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %778 : int[] = prim::ListConstruct(%776, %777), scope: __module.cnn/__module.cnn.pooling3
#   %779 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.pooling3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %780 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.pooling3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %781 : int[] = prim::ListConstruct(%779, %780), scope: __module.cnn/__module.cnn.pooling3
#   %782 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.pooling3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %783 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.pooling3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %784 : int[] = prim::ListConstruct(%782, %783), scope: __module.cnn/__module.cnn.pooling3
#   %785 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.pooling3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %input.19 : Float(20, 512, 2, 8) = aten::max_pool2d(%input.18, %775, %778, %781, %784, %785), scope: __module.cnn/__module.cnn.pooling3 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:539:0
#   %787 : Tensor = prim::GetAttr[name="bias"](%568)
#   %788 : Tensor = prim::GetAttr[name="weight"](%568)
#   %789 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv6 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %790 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv6 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %791 : int[] = prim::ListConstruct(%789, %790), scope: __module.cnn/__module.cnn.conv6
#   %792 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv6 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %793 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv6 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %794 : int[] = prim::ListConstruct(%792, %793), scope: __module.cnn/__module.cnn.conv6
#   %795 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv6 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %796 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv6 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %797 : int[] = prim::ListConstruct(%795, %796), scope: __module.cnn/__module.cnn.conv6
#   %798 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv6 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %799 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv6 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %800 : int = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv6 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %801 : int[] = prim::ListConstruct(%799, %800), scope: __module.cnn/__module.cnn.conv6
#   %802 : int = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv6 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %803 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv6 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %804 : bool = prim::Constant[value=0](), scope: __module.cnn/__module.cnn.conv6 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %805 : bool = prim::Constant[value=1](), scope: __module.cnn/__module.cnn.conv6 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %input.20 : Float(20, 512, 1, 7) = aten::_convolution(%input.19, %788, %787, %791, %794, %797, %798, %801, %802, %803, %804, %805), scope: __module.cnn/__module.cnn.conv6 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\conv.py:350:0
#   %conv.1 : Float(20, 512, 1, 7) = aten::relu_(%input.20), scope: __module.cnn/__module.cnn.relu6 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1061:0
#   %296 : int = prim::Constant[value=0]() # <ipython-input-3-d62b689f6451>:89:0
#   %297 : int = aten::size(%conv.1, %296) # <ipython-input-3-d62b689f6451>:89:0
#   %batch : Long() = prim::NumToTensor(%297)
#   %309 : int = aten::Int(%batch)
#   %299 : int = prim::Constant[value=1]() # <ipython-input-3-d62b689f6451>:89:0
#   %300 : int = aten::size(%conv.1, %299) # <ipython-input-3-d62b689f6451>:89:0
#   %channel : Long() = prim::NumToTensor(%300)
#   %302 : int = prim::Constant[value=2]() # <ipython-input-3-d62b689f6451>:89:0
#   %303 : int = aten::size(%conv.1, %302) # <ipython-input-3-d62b689f6451>:89:0
#   %height : Long() = prim::NumToTensor(%303)
#   %305 : int = prim::Constant[value=3]() # <ipython-input-3-d62b689f6451>:89:0
#   %306 : int = aten::size(%conv.1, %305) # <ipython-input-3-d62b689f6451>:89:0
#   %width : Long() = prim::NumToTensor(%306)
#   %311 : int = aten::Int(%width)
#   %308 : Long() = aten::mul(%channel, %height) # <ipython-input-3-d62b689f6451>:91:0
#   %310 : int = aten::Int(%308)
#   %312 : int[] = prim::ListConstruct(%309, %310, %311)
#   %conv : Float(20, 512, 7) = aten::view(%conv.1, %312) # <ipython-input-3-d62b689f6451>:91:0
#   %314 : int = prim::Constant[value=2]() # <ipython-input-3-d62b689f6451>:92:0
#   %315 : int = prim::Constant[value=0]() # <ipython-input-3-d62b689f6451>:92:0
#   %316 : int = prim::Constant[value=1]() # <ipython-input-3-d62b689f6451>:92:0
#   %317 : int[] = prim::ListConstruct(%314, %315, %316)
#   %input.21 : Float(7, 20, 512) = aten::permute(%conv, %317) # <ipython-input-3-d62b689f6451>:92:0
#   %808 : Tensor = prim::GetAttr[name="bias"](%515)
#   %809 : Tensor = prim::GetAttr[name="weight"](%515)
#   %810 : Float(512, 64) = aten::t(%809), scope: __module.map_to_seq # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1612:0
#   %output.1 : Float(7, 20, 64) = aten::matmul(%input.21, %810), scope: __module.map_to_seq # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1612:0
#   %812 : int = prim::Constant[value=1](), scope: __module.map_to_seq # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1614:0
#   %input.22 : Float(7, 20, 64) = aten::add_(%output.1, %808, %812), scope: __module.map_to_seq # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1614:0
#   %814 : Tensor = prim::GetAttr[name="bias_hh_l0_reverse"](%524)
#   %815 : Tensor = prim::GetAttr[name="bias_ih_l0_reverse"](%524)
#   %816 : Tensor = prim::GetAttr[name="weight_hh_l0_reverse"](%524)
#   %817 : Tensor = prim::GetAttr[name="weight_ih_l0_reverse"](%524)
#   %818 : Tensor = prim::GetAttr[name="bias_hh_l0"](%524)
#   %819 : Tensor = prim::GetAttr[name="bias_ih_l0"](%524)
#   %820 : Tensor = prim::GetAttr[name="weight_hh_l0"](%524)
#   %821 : Tensor = prim::GetAttr[name="weight_ih_l0"](%524)
#   %822 : int = prim::Constant[value=1](), scope: __module.rnn1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:552:0
#   %823 : int = aten::size(%input.22, %822), scope: __module.rnn1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:552:0
#   %max_batch_size.1 : Long() = prim::NumToTensor(%823), scope: __module.rnn1
#   %825 : int = aten::Int(%max_batch_size.1), scope: __module.rnn1
#   %826 : int = prim::Constant[value=2](), scope: __module.rnn1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:560:0
#   %827 : int = prim::Constant[value=256](), scope: __module.rnn1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:560:0
#   %828 : int[] = prim::ListConstruct(%826, %825, %827), scope: __module.rnn1
#   %829 : int = prim::Constant[value=6](), scope: __module.rnn1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:560:0
#   %830 : int = prim::Constant[value=0](), scope: __module.rnn1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:560:0
#   %831 : Device = prim::Constant[value="cuda:0"](), scope: __module.rnn1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:560:0
#   %832 : bool = prim::Constant[value=0](), scope: __module.rnn1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:560:0
#   %hx.1 : Float(2, 20, 256) = aten::zeros(%828, %829, %830, %831, %832), scope: __module.rnn1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:560:0
#   %834 : Tensor[] = prim::ListConstruct(%hx.1, %hx.1), scope: __module.rnn1
#   %835 : Tensor[] = prim::ListConstruct(%821, %820, %819, %818, %817, %816, %815, %814), scope: __module.rnn1
#   %836 : bool = prim::Constant[value=1](), scope: __module.rnn1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:570:0
#   %837 : int = prim::Constant[value=1](), scope: __module.rnn1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:570:0
#   %838 : float = prim::Constant[value=0.](), scope: __module.rnn1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:570:0
#   %839 : bool = prim::Constant[value=0](), scope: __module.rnn1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:570:0
#   %840 : bool = prim::Constant[value=1](), scope: __module.rnn1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:570:0
#   %841 : bool = prim::Constant[value=0](), scope: __module.rnn1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:570:0
#   %input.23 : Float(7, 20, 512), %843 : Float(2, 20, 256), %844 : Float(2, 20, 256) = aten::lstm(%input.22, %834, %835, %836, %837, %838, %839, %840, %841), scope: __module.rnn1 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:570:0
#   %845 : Tensor = prim::GetAttr[name="bias_hh_l0_reverse"](%533)
#   %846 : Tensor = prim::GetAttr[name="bias_ih_l0_reverse"](%533)
#   %847 : Tensor = prim::GetAttr[name="weight_hh_l0_reverse"](%533)
#   %848 : Tensor = prim::GetAttr[name="weight_ih_l0_reverse"](%533)
#   %849 : Tensor = prim::GetAttr[name="bias_hh_l0"](%533)
#   %850 : Tensor = prim::GetAttr[name="bias_ih_l0"](%533)
#   %851 : Tensor = prim::GetAttr[name="weight_hh_l0"](%533)
#   %852 : Tensor = prim::GetAttr[name="weight_ih_l0"](%533)
#   %853 : int = prim::Constant[value=1](), scope: __module.rnn2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:552:0
#   %854 : int = aten::size(%input.23, %853), scope: __module.rnn2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:552:0
#   %max_batch_size : Long() = prim::NumToTensor(%854), scope: __module.rnn2
#   %856 : int = aten::Int(%max_batch_size), scope: __module.rnn2
#   %857 : int = prim::Constant[value=2](), scope: __module.rnn2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:560:0
#   %858 : int = prim::Constant[value=256](), scope: __module.rnn2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:560:0
#   %859 : int[] = prim::ListConstruct(%857, %856, %858), scope: __module.rnn2
#   %860 : int = prim::Constant[value=6](), scope: __module.rnn2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:560:0
#   %861 : int = prim::Constant[value=0](), scope: __module.rnn2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:560:0
#   %862 : Device = prim::Constant[value="cuda:0"](), scope: __module.rnn2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:560:0
#   %863 : bool = prim::Constant[value=0](), scope: __module.rnn2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:560:0
#   %hx : Float(2, 20, 256) = aten::zeros(%859, %860, %861, %862, %863), scope: __module.rnn2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:560:0
#   %865 : Tensor[] = prim::ListConstruct(%hx, %hx), scope: __module.rnn2
#   %866 : Tensor[] = prim::ListConstruct(%852, %851, %850, %849, %848, %847, %846, %845), scope: __module.rnn2
#   %867 : bool = prim::Constant[value=1](), scope: __module.rnn2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:570:0
#   %868 : int = prim::Constant[value=1](), scope: __module.rnn2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:570:0
#   %869 : float = prim::Constant[value=0.](), scope: __module.rnn2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:570:0
#   %870 : bool = prim::Constant[value=0](), scope: __module.rnn2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:570:0
#   %871 : bool = prim::Constant[value=1](), scope: __module.rnn2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:570:0
#   %872 : bool = prim::Constant[value=0](), scope: __module.rnn2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:570:0
#   %input : Float(7, 20, 512), %874 : Float(2, 20, 256), %875 : Float(2, 20, 256) = aten::lstm(%input.23, %865, %866, %867, %868, %869, %870, %871, %872), scope: __module.rnn2 # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\modules\rnn.py:570:0
#   %876 : Tensor = prim::GetAttr[name="bias"](%536)
#   %877 : Tensor = prim::GetAttr[name="weight"](%536)
#   %878 : Float(512, 11) = aten::t(%877), scope: __module.dense # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1612:0
#   %output : Float(7, 20, 11) = aten::matmul(%input, %878), scope: __module.dense # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1612:0
#   %880 : int = prim::Constant[value=1](), scope: __module.dense # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1614:0
#   %881 : Float(7, 20, 11) = aten::add_(%output, %876, %880), scope: __module.dense # C:\Users\liuxuyang\AppData\Roaming\Python\Python37\site-packages\torch\nn\functional.py:1614:0
#   return (%881)

# %%
stride with padding: (n + 2p - f)/s + 1
conv0 (32+2-3)/1+1 = 32 (32,32)
conv1
